# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/MachineLearningNotebooks/how-to-use-azureml/explain-model/azure-integration/remote-explanation/explain-model-on-amlcompute.png)

# %% [markdown]
# # Train and explain models remotely via Azure Machine Learning Compute
#
#
# _**This notebook showcases how to use the Azure Machine Learning Interpretability SDK to train and explain a regression model remotely on an Azure Machine Leanrning Compute Target (AMLCompute).**_
#
#
#
#
# ## Table of Contents
#
# 1. [Introduction](#Introduction)
# 1. [Setup](#Setup)
#     1. Initialize a Workspace
#     1. Create an Experiment
#     1. Introduction to AmlCompute
#     1. Submit an AmlCompute run in a few different ways
#         1. Option 1: Provision as a run based compute target
#         1. Option 2: Provision as a persistent compute target (Basic)
#         1. Option 3: Provision as a persistent compute target (Advanced)
# 1. Additional operations to perform on AmlCompute
# 1. [Download model explanations from Azure Machine Learning Run History](#Download)
# 1. [Visualize explanations](#Visualize)
# 1. [Next steps](#Next)

# %% [markdown]
# ## Introduction
#
# This notebook showcases how to train and explain a regression model remotely via Azure Machine Learning Compute (AMLCompute), and download the calculated explanations locally for visualization.
# It demonstrates the API calls that you need to make to submit a run for training and explaining a model to AMLCompute, download the compute explanations remotely, and visualizing the global and local explanations via a visualization dashboard that provides an interactive way of discovering patterns in model predictions and downloaded explanations.
#
# We will showcase one of the tabular data explainers: TabularExplainer (SHAP).
#
# ![](./images/explanations-run-history.png)

# %% [markdown]
# ## Setup

# %%
# Check core SDK version number
import azureml.core

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.4.0

# %% [markdown]
# ## Initialize a Workspace
#
# Connect to the workspace

# %%
from azureml.core import Workspace, Dataset

#ws = Workspace.from_config()
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication(tenant_id="19479f88-8eac-45d2-a1bf-69d33854a3fa")
# Get Workspace defined in by default config.json file
# ws = Workspace.from_config()
ws = Workspace(subscription_id="5e22d967-997b-49c7-8ca1-7ccfbf37e621",
               resource_group="rg-cbui-course532",
               workspace_name="amlwksphol",
               auth=interactive_auth)
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep='\n')
# Out:
# amlwksphol
# rg-cbui-course532
# westus
# 5e22d967-997b-49c7-8ca1-7ccfbf37e621

# %% [markdown]
# ## Create An Experiment
#
# **Experiment** is a logical container in an Azure ML Workspace. It hosts run records which can include run metrics and output artifacts from your experiments.

# %%
from azureml.core import Experiment
experiment_name = 'explainer-remote-run-on-amlcompute'
experiment = Experiment(workspace=ws, name=experiment_name)

# %% [markdown]
# ## Introduction to AmlCompute
#
# Azure Machine Learning Compute is managed compute infrastructure that allows the user to easily create single to multi-node compute of the appropriate VM Family. It is created **within your workspace region** and is a resource that can be used by other users in your workspace. It autoscales by default to the max_nodes, when a job is submitted, and executes in a containerized environment packaging the dependencies as specified by the user.
#
# Since it is managed compute, job scheduling and cluster management are handled internally by Azure Machine Learning service.
#
# For more information on Azure Machine Learning Compute, please read [this article](https://docs.microsoft.com/azure/machine-learning/service/how-to-set-up-training-targets#amlcompute)
#
# **Note**: As with other Azure services, there are limits on certain resources (for eg. AmlCompute quota) associated with the Azure Machine Learning service. Please read [this article](https://docs.microsoft.com/azure/machine-learning/service/how-to-manage-quotas) on the default limits and how to request more quota.

# %% [markdown]
# ## Submit an AmlCompute run in a few different ways
#
# First lets check which VM families are available in your region. Azure is a regional service and some specialized SKUs (especially GPUs) are only available in certain regions. Since AmlCompute is created in the region of your workspace, we will use the supported_vms () function to see if the VM family we want to use ('STANDARD_D2_V2') is supported.
#
# You can also pass a different region to check availability and then re-create your workspace in that region through the [configuration notebook](../../../configuration.ipynb)

# %% [markdown]
# ### Create project directory
#
# Create a directory that will contain all the necessary code from your local machine that you will need access to on the remote resource. This includes the training script, and any additional files your training script depends on

# %%
import os
import shutil

project_folder = './explainer-remote-run-on-amlcompute'
os.makedirs(project_folder, exist_ok=True)
shutil.copy('train_explain.py', project_folder)
# Out:
# './explainer-remote-run-on-amlcompute/train_explain.py'

# %% [markdown]
# Note: if you need to cancel a run, you can follow [these instructions](https://aka.ms/aml-docs-cancel-run).

# %% [markdown]
# ### Fetch or create the compute target
#
# We are going to use the compute target you had created before (make sure you provide the same name here in the variable `cpu_cluster_name`.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Reference your existing cluster
cpu_cluster_name = "cpucluster"

cpu_cluster = ws.compute_targets[cpu_cluster_name]

# %% [markdown]
# The above code will throw an error if you didn't set the cluster up in the first part of the workshop. In that case, you can provision a cluster here by executing the next cell.
#
# **Note:** By default a cluster autoscales from 0 nodes and provisions dedicated VMs to run your job in a container. This is useful when you want to continously re-use the same target, debug it between jobs or simply share the resource with other users of your workspace.
#
# * `vm_size`: VM family of the nodes provisioned by AmlCompute. Simply choose from the supported_vmsizes() above
# * `max_nodes`: Maximum nodes to autoscale to while running a job on AmlCompute

# %%
# If you didn't create the cluster in the first part of the workshop, this code will create it
#compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
#                                                       max_nodes=8, 
#                                                       idle_seconds_before_scaledown=7200)
#cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)
#cpu_cluster.wait_for_completion(show_output=True)

# %% [markdown]
# ### Configure & Run

# %%
from azureml.train.estimator import Estimator

pip_packages = [
                'azureml-defaults==1.0.76', 'azureml-core==1.0.76', 'azureml-telemetry==1.0.76',
                'azureml-dataprep==1.1.31', 'joblib==0.14.0', 'sklearn-pandas==1.7.0', 'pandas==0.23.4',
                'azureml-contrib-interpret'
               ]

estimator = Estimator(source_directory=project_folder, 
                      compute_target=cpu_cluster,
                      entry_script='train_explain.py',
                      pip_packages=pip_packages,
                      conda_packages=['scikit-learn==0.20.3'],
                      inputs=[ws.datasets['employeeattrition'].as_named_input('attrition')])

run = experiment.submit(estimator)
run
# Out:
# Run(Experiment: explainer-remote-run-on-amlcompute,
# Id: explainer-remote-run-on-amlcompute_1589985163_b05fc2f2,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
from azureml.widgets import RunDetails
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %% [markdown]
# ![](images/aml-run.png)

# %% [markdown]
# ## (OPTIONAL) Additional operations to perform on AmlCompute Cluster
#
# You can perform more operations on AmlCompute such as updating the node counts or deleting the compute.

# %%
# Get_status () gets the latest status of the AmlCompute target
cpu_cluster.get_status().serialize()
# Out:
# {'currentNodeCount': 0,
#  'targetNodeCount': 0,
#  'nodeStateCounts': {'preparingNodeCount': 0,
#   'runningNodeCount': 0,
#   'idleNodeCount': 0,
#   'unusableNodeCount': 0,
#   'leavingNodeCount': 0,
#   'preemptedNodeCount': 0},
#  'allocationState': 'Steady',
#  'allocationStateTransitionTime': '2020-05-18T21:15:21.645000+00:00',
#  'errors': None,
#  'creationTime': '2020-05-18T19:32:16.878038+00:00',
#  'modifiedTime': '2020-05-18T19:33:04.220891+00:00',
#  'provisioningState': 'Succeeded',
#  'provisioningStateTransitionTime': None,
#  'scaleSettings': {'minNodeCount': 0,
#   'maxNodeCount': 4,
#   'nodeIdleTimeBeforeScaleDown': 'PT600S'},
#  'vmPriority': 'Dedicated',
#  'vmSize': 'STANDARD_DS2_V2'}

# %%
# The update() call takes in the min_nodes, max_nodes and idle_seconds_before_scaledown and updates the AmlCompute target
# cpu_cluster.update(min_nodes=1)
# cpu_cluster.update(max_nodes=10)
#cpu_cluster.update(idle_seconds_before_scaledown=7200)
# cpu_cluster.update(min_nodes=2, max_nodes=4, idle_seconds_before_scaledown=600)

# %%
# Delete() is used to deprovision and delete the AmlCompute target. Useful if you want to re-use the compute name 
# 'cpu-cluster' in this case but use a different VM family for instance.

# cpu_cluster.delete()

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: explainer-remote-run-on-amlcompute_1589985163_b05fc2f2
# Web View: https://ml.azure.com/experiments/explainer-remote-run-on-amlcompute/runs/explainer-remote-run-on-amlcompute_1589985163_b05fc2f2?wsid=/subscriptions/5e22d967-997b-49c7-8ca1-7ccfbf37e621/resourcegroups/rg-cbui-course532/workspaces/amlwksphol
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/05/20 14:33:02 Downloading source code...
# 2020/05/20 14:33:03 Finished downloading source code
# 2020/05/20 14:33:03 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/05/20 14:33:04 Successfully set up Docker network: acb_default_network
# 2020/05/20 14:33:04 Setting up Docker configuration...
# 2020/05/20 14:33:04 Successfully set up Docker configuration
# 2020/05/20 14:33:04 Logging in to registry: amlwkspholef3210b7.azurecr.io
# 2020/05/20 14:33:06 Successfully logged into amlwkspholef3210b7.azurecr.io
# 2020/05/20 14:33:06 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/20 14:33:06 Scanning for dependencies...
# 2020/05/20 14:33:06 Successfully scanned dependencies
# 2020/05/20 14:33:06 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/14 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/14 : USER root
#  ---> Running in 834dc1228e57
# Removing intermediate container 834dc1228e57
#  ---> 62a63ae45670
# Step 3/14 : RUN mkdir -p $HOME/.cache
#  ---> Running in 31364998e5c8
# Removing intermediate container 31364998e5c8
#  ---> 50f681588712
# Step 4/14 : WORKDIR /
#  ---> Running in f2c47656ac8e
# Removing intermediate container f2c47656ac8e
#  ---> d6acddb8b9b5
# Step 5/14 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 5224130922cf
# Step 6/14 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 8b95b0a495c2
# Removing intermediate container 8b95b0a495c2
#  ---> 329a45314e89
# Step 7/14 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 5f953f0febff
# Step 8/14 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in e7988d994d3a
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# six-1.14.0           | 27 KB     |            |   0%
# six-1.14.0           | 27 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########   |  81%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########  |  90%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# scipy-1.4.1          | 18.9 MB   |            |   0%
# scipy-1.4.1          | 18.9 MB   | ##2        |  23%
# scipy-1.4.1          | 18.9 MB   | #####9     |  60%
# scipy-1.4.1          | 18.9 MB   | #######5   |  76%
# scipy-1.4.1          | 18.9 MB   | ########9  |  90%
# scipy-1.4.1          | 18.9 MB   | #########9 | 100%
# scipy-1.4.1          | 18.9 MB   | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | #########8 |  99%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# numpy-1.18.1         | 5 KB      |            |   0%
# numpy-1.18.1         | 5 KB      | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########4  |  84%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# mkl_fft-1.0.15       | 173 KB    |            |   0%
# mkl_fft-1.0.15       | 173 KB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | #######8   |  78%
# pip-20.0.2           | 1.9 MB    | #########4 |  94%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.1 MB    | #########5 |  96%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########7 |  98%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 5          |   6%
# mkl-2019.4           | 204.1 MB  | 9          |  10%
# mkl-2019.4           | 204.1 MB  | #3         |  13%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | ##         |  20%
# mkl-2019.4           | 204.1 MB  | ##3        |  23%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####1      |  41%
# mkl-2019.4           | 204.1 MB  | ####4      |  44%
# mkl-2019.4           | 204.1 MB  | ####7      |  48%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####4     |  55%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######1    |  62%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######8    |  68%
# mkl-2019.4           | 204.1 MB  | #######1   |  72%
# mkl-2019.4           | 204.1 MB  | #######5   |  75%
# mkl-2019.4           | 204.1 MB  | #######7   |  78%
# mkl-2019.4           | 204.1 MB  | #######9   |  80%
# mkl-2019.4           | 204.1 MB  | ########1  |  81%
#
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########4  |  84%
# mkl-2019.4           | 204.1 MB  | ########4  |  84%
# mkl-2019.4           | 204.1 MB  | ########4  |  84%
# mkl-2019.4           | 204.1 MB  | ########4  |  84%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  85%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  86%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
#
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  88%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  89%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | ########9  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  91%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  92%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  93%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
#
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########5 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########7 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
#
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | #########3 |  93%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #6         |  17%
# python-3.6.2         | 27.0 MB   | ####1      |  42%
# python-3.6.2         | 27.0 MB   | ######6    |  66%
# python-3.6.2         | 27.0 MB   | ########1  |  82%
# python-3.6.2         | 27.0 MB   | #########2 |  92%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########6 |  96%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########8  |  88%
# tk-8.6.8             | 3.1 MB    | #########7 |  97%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# numpy-base-1.18.1    | 5.2 MB    |            |   0%
# numpy-base-1.18.1    | 5.2 MB    | #######5   |  76%
# numpy-base-1.18.1    | 5.2 MB    | #########8 |  99%
# numpy-base-1.18.1    | 5.2 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######9    |  69%
# libgcc-ng-9.1.0      | 8.1 MB    | ########9  |  90%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    |            |   1%
# sqlite-3.23.1        | 1.5 MB    | ########5  |  85%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# setuptools-46.4.0    | 646 KB    |            |   0%
# setuptools-46.4.0    | 646 KB    | ########3  |  84%
# setuptools-46.4.0    | 646 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# scikit-learn-0.20.3  | 5.7 MB    |            |   0%
# scikit-learn-0.20.3  | 5.7 MB    | #######5   |  76%
# scikit-learn-0.20.3  | 5.7 MB    | #########8 |  98%
# scikit-learn-0.20.3  | 5.7 MB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults==1.0.76
#   Downloading azureml_defaults-1.0.76-py2.py3-none-any.whl (2.9 kB)
# Collecting azureml-core==1.0.76
#   Downloading azureml_core-1.0.76-py2.py3-none-any.whl (1.2 MB)
# Collecting azureml-telemetry==1.0.76
#   Downloading azureml_telemetry-1.0.76-py3-none-any.whl (32 kB)
# Collecting azureml-dataprep==1.1.31
#   Downloading azureml_dataprep-1.1.31-py3-none-any.whl (26.9 MB)
# Collecting joblib==0.14.0
#   Downloading joblib-0.14.0-py2.py3-none-any.whl (294 kB)
# Collecting sklearn-pandas==1.7.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas==0.23.4
#   Downloading pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9 MB)
# Collecting azureml-contrib-interpret
#   Downloading azureml_contrib_interpret-1.5.0-py3-none-any.whl (19 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages (from azureml-core==1.0.76->-r /azureml-environment-setup/condaenv.skz5_2yd.requirements.txt (line 2)) (1.14.0)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.14-py2.py3-none-any.whl (84 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-9.0.0-py2.py3-none-any.whl (807 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.3-py2.py3-none-any.whl (53 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azureml-dataprep-native<14.0.0,>=13.1.0
#   Downloading azureml_dataprep_native-13.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting dotnetcore2>=2.1.9
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Requirement already satisfied: numpy>=1.6.1 in /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages (from sklearn-pandas==1.7.0->-r /azureml-environment-setup/condaenv.skz5_2yd.requirements.txt (line 6)) (1.18.1)
# Requirement already satisfied: scikit-learn>=0.15.0 in /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages (from sklearn-pandas==1.7.0->-r /azureml-environment-setup/condaenv.skz5_2yd.requirements.txt (line 6)) (0.20.3)
# Requirement already satisfied: scipy>=0.14 in /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages (from sklearn-pandas==1.7.0->-r /azureml-environment-setup/condaenv.skz5_2yd.requirements.txt (line 6)) (1.4.1)
# Collecting azureml-interpret~=1.5.0
#   Downloading azureml_interpret-1.5.0-py3-none-any.whl (45 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting Werkzeug>=0.14
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core==1.0.76->-r /azureml-environment-setup/condaenv.skz5_2yd.requirements.txt (line 2)) (2020.4.5.1)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting interpret-community==0.10.*
#   Downloading interpret_community-0.10.2-py3-none-any.whl (5.4 MB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting interpret-core[required]<=0.1.21,>=0.1.20
#   Downloading interpret_core-0.1.21-py3-none-any.whl (8.3 MB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
# Collecting packaging
#   Downloading packaging-20.4-py2.py3-none-any.whl (37 kB)
# Collecting tqdm>4.25.0
#   Downloading tqdm-4.46.0-py2.py3-none-any.whl (63 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, dill, shap
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=162ef077f6bd9b45e59ff2de3d9594d7563d280b6ad8f5f9ac4ff4306de544cb
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=13de5161b7cddd47cb66474dcb259f1a707716dab2a782dcfa47bb8723ae538b
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=83a2c530c5fbadc07f592579de09469b259baae79e653be81b54cf0a7eac1ecc
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.34.0-cp36-cp36m-linux_x86_64.whl size=387823 sha256=2aa30c9e823dc96a847e26fce61dbf3e313a4acc0bf915cfa256664db42ad6ab
#   Stored in directory: /root/.cache/pip/wheels/88/56/c6/630b200696678c506f3057a1e7573c086e50d59fdcffcbfd04
# Successfully built json-logging-py liac-arff dill shap
# Installing collected packages: pytz, PyJWT, backports.weakref, backports.tempfile, contextlib2, pathspec, urllib3, idna, chardet, requests, oauthlib, requests-oauthlib, isodate, msrest, python-dateutil, pycparser, cffi, cryptography, adal, msrestazure, azure-common, azure-mgmt-authorization, azure-mgmt-containerregistry, azure-graphrbac, azure-mgmt-resource, jeepney, SecretStorage, pyopenssl, pyasn1, ndg-httpsclient, azure-mgmt-storage, azure-mgmt-keyvault, zipp, importlib-metadata, jsonpickle, jmespath, websocket-client, docker, ruamel.yaml, azureml-core, applicationinsights, click, itsdangerous, MarkupSafe, Jinja2, Werkzeug, flask, liac-arff, pandas, dill, azureml-model-management-sdk, configparser, gunicorn, json-logging-py, azureml-defaults, azureml-telemetry, azureml-dataprep-native, cloudpickle, distro, dotnetcore2, azureml-dataprep, joblib, sklearn-pandas, interpret-core, tqdm, shap, pyparsing, packaging, interpret-community, azureml-interpret, azureml-contrib-interpret
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 Werkzeug-1.0.1 adal-1.2.3 applicationinsights-0.11.9 azure-common-1.1.25 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-9.0.0 azure-mgmt-storage-10.0.0 azureml-contrib-interpret-1.5.0 azureml-core-1.0.76 azureml-dataprep-1.1.31 azureml-dataprep-native-13.2.0 azureml-defaults-1.0.76 azureml-interpret-1.5.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-telemetry-1.0.76 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.4.1 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.9.2 dill-0.3.1.1 distro-1.5.0 docker-4.2.0 dotnetcore2-2.1.14 flask-1.0.3 gunicorn-19.9.0 idna-2.9 importlib-metadata-1.6.0 interpret-community-0.10.2 interpret-core-0.1.21 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 joblib-0.14.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msrest-0.6.14 msrestazure-0.6.3 ndg-httpsclient-0.5.1 oauthlib-3.1.0 packaging-20.4 pandas-0.23.4 pathspec-0.8.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 pyparsing-2.4.7 python-dateutil-2.8.1 pytz-2020.1 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 shap-0.34.0 sklearn-pandas-1.7.0 tqdm-4.46.0 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container e7988d994d3a
#  ---> f56388afa940
# Step 9/14 : ENV PATH /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/bin:$PATH
#  ---> Running in 912fea67a6f9
# Removing intermediate container 912fea67a6f9
#  ---> eace2f76f8f7
# Step 10/14 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc
#  ---> Running in 208e8633435d
# Removing intermediate container 208e8633435d
#  ---> 398981bc674f
# Step 11/14 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib:$LD_LIBRARY_PATH
#  ---> Running in 90c5cf205241
# Removing intermediate container 90c5cf205241
#  ---> bdf59197b159
# Step 12/14 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> ea2b3f45d789
# Step 13/14 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 8c4f4a62ba30
# Removing intermediate container 8c4f4a62ba30
#  ---> 629c3d6a55bf
# Step 14/14 : CMD ["bash"]
#  ---> Running in be8f2d03a5f6
# Removing intermediate container be8f2d03a5f6
#  ---> e2a57a77334a
# Successfully built e2a57a77334a
# Successfully tagged amlwkspholef3210b7.azurecr.io/azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f:latest
# 2020/05/20 14:36:57 Successfully executed container: acb_step_0
# 2020/05/20 14:36:57 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/20 14:36:57 Pushing image: amlwkspholef3210b7.azurecr.io/azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f:latest, attempt 1
# The push refers to repository [amlwkspholef3210b7.azurecr.io/azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f]
# 48967d1bb007: Preparing
# 1f75d1d0b001: Preparing
# 4fd2c32e733e: Preparing
# 88673d418ad2: Preparing
# ce4bc6bd8eac: Preparing
# 7a5ba85a3cd7: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# 7a5ba85a3cd7: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# 48967d1bb007: Pushed
# 88673d418ad2: Pushed
# ce4bc6bd8eac: Pushed
# 4fd2c32e733e: Pushed
# 7a5ba85a3cd7: Pushed
# e1171d4d60ca: Pushed
# 6ef1a8ae63b7: Pushed
#
# 340dc32eb998: Pushed
# 0e259b09e5f4: Pushed
# 85389f9ead9e: Pushed
# ccdb13a20bf2: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# f2608f66a0e3: Pushed
# df18b66efaa6: Pushed
# 29f36b5893dc: Pushed
# 1f75d1d0b001: Pushed
# latest: digest: sha256:81341bb1149c0fcbffdd9dac5ec75b9a55f7e0ce0d566e71579dbf1feabf43f7 size: 3883
# 2020/05/20 14:39:15 Successfully pushed image: amlwkspholef3210b7.azurecr.io/azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f:latest
# 2020/05/20 14:39:15 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 231.672527)
# 2020/05/20 14:39:15 Populating digests for step ID: acb_step_0...
# 2020/05/20 14:39:17 Successfully populated digests for step ID: acb_step_0
# 2020/05/20 14:39:17 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 137.688985)
# 2020/05/20 14:39:17 The following dependencies were found:
# 2020/05/20 14:39:17
# - image:
#     registry: amlwkspholef3210b7.azurecr.io
#     repository: azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f
#     tag: latest
#     digest: sha256:81341bb1149c0fcbffdd9dac5ec75b9a55f7e0ce0d566e71579dbf1feabf43f7
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: cf2 was successful after 6m16s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt
# ========================================================================================================================
#
# 2020-05-20T14:43:09Z Starting output-watcher...
# 2020-05-20T14:43:09Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
#
# Streaming azureml-logs/65_job_prep-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt
# ===============================================================================================================
#
# Entering job preparation. Current time:2020-05-20T14:44:24.005081
# Starting job preparation. Current time:2020-05-20T14:44:24.501400
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 7ea5f505-03bf-431d-837b-14c2b6a7cd25
# Starting the daemon thread to refresh tokens in background for process with pid = 49
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2020/05/20 14:44:27 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-20T14:44:29.194048
# Starting the daemon thread to refresh tokens in background for process with pid = 102
# Entering Run History Context Manager.
# Preparing to call script [ train_explain.py ] with arguments: []
# After variable expansion, calling script [ train_explain.py ] with arguments: []
#
# adal==1.2.3
# applicationinsights==0.11.9
# azure-common==1.1.25
# azure-graphrbac==0.61.1
# azure-mgmt-authorization==0.60.0
# azure-mgmt-containerregistry==2.8.0
# azure-mgmt-keyvault==2.2.0
# azure-mgmt-resource==9.0.0
# azure-mgmt-storage==10.0.0
# azureml-contrib-interpret==1.5.0
# azureml-core==1.0.76
# azureml-dataprep==1.1.31
# azureml-dataprep-native==13.2.0
# azureml-defaults==1.0.76
# azureml-interpret==1.5.0
# azureml-model-management-sdk==1.0.1b6.post1
# azureml-telemetry==1.0.76
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# certifi==2020.4.5.1
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.4.1
# configparser==3.7.4
# contextlib2==0.6.0.post1
# cryptography==2.9.2
# dill==0.3.1.1
# distro==1.5.0
# docker==4.2.0
# dotnetcore2==2.1.14
# Flask==1.0.3
# gunicorn==19.9.0
# idna==2.9
# importlib-metadata==1.6.0
# interpret-community==0.10.2
# interpret-core==0.1.21
# isodate==0.6.0
# itsdangerous==1.1.0
# jeepney==0.4.3
# Jinja2==2.11.2
# jmespath==0.10.0
# joblib==0.14.0
# json-logging-py==0.2
# jsonpickle==1.4.1
# liac-arff==2.4.0
# MarkupSafe==1.1.1
# mkl-fft==1.0.15
# mkl-random==1.1.0
# mkl-service==2.3.0
# msrest==0.6.14
# msrestazure==0.6.3
# ndg-httpsclient==0.5.1
# numpy==1.18.1
# oauthlib==3.1.0
# packaging==20.4
# pandas==0.23.4
# pathspec==0.8.0
# pyasn1==0.4.8
# pycparser==2.20
# PyJWT==1.7.1
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# python-dateutil==2.8.1
# pytz==2020.1
# requests==2.23.0
# requests-oauthlib==1.3.0
# ruamel.yaml==0.15.89
# scikit-learn==0.20.3
# scipy==1.4.1
# SecretStorage==3.1.2
# shap==0.34.0
# six==1.14.0
# sklearn-pandas==1.7.0
# tqdm==4.46.0
# urllib3==1.25.9
# websocket-client==0.57.0
# Werkzeug==1.0.1
# zipp==3.1.0
# SDK version: 1.0.76
# load dataset
# /azureml-envs/azureml_e158b0e389821d00d72b205b3dcc7bbc/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py:689: UserWarning: Please install pyarrow>=0.11.0 for improved performance of to_pandas_dataframe. You can ensure the correct version is installed by running: pip install azureml-dataprep[pandas].
#   warnings.warn('Please install pyarrow>=0.11.0 for improved performance of to_pandas_dataframe. '
#    Age          ...           YearsWithCurrManager
# 0   41          ...                              5
# 1   49          ...                              7
# 2   37          ...                              0
# 3   33          ...                              0
# 4   27          ...                              2
#
# [5 rows x 35 columns]
# INFO - Initializing logging file for interpret-community
# Could not import lightgbm, required if using LGBMExplainableModel
# train model
# create explainer
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# INFO - Failed to initialize explainer <class 'interpret_community.shap.tree_explainer.TreeExplainer'> due to error: Model type not yet supported by TreeExplainer: <class 'sklearn.linear_model.logistic.LogisticRegression'>
# INFO - Failed to initialize explainer <class 'interpret_community.shap.deep_explainer.DeepExplainer'> due to error: No module named 'tensorflow'
# The option feature_dependence has been renamed to feature_perturbation!
# The option feature_perturbation="independent" is has been renamed to feature_perturbation="interventional"!
# INFO - Initialized valid explainer LinearExplainer with args {'explain_subset': None, 'features': Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object'), 'classes': ['Not leaving', 'leaving']}
# upload explanation
# Streaming azureml-logs/75_job_post-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt
# ===============================================================================================================
#
# Entering job release. Current time:2020-05-20T14:44:53.720428
# Starting job release. Current time:2020-05-20T14:44:54.714006
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 301
# Entering context manager injector. Current time:2020-05-20T14:44:54.727724
# Job release is complete. Current time:2020-05-20T14:44:55.974819
#
# Execution Summary
# =================
# RunId: explainer-remote-run-on-amlcompute_1589985163_b05fc2f2
# Web View: https://ml.azure.com/experiments/explainer-remote-run-on-amlcompute/runs/explainer-remote-run-on-amlcompute_1589985163_b05fc2f2?wsid=/subscriptions/5e22d967-997b-49c7-8ca1-7ccfbf37e621/resourcegroups/rg-cbui-course532/workspaces/amlwksphol
# {'runId': 'explainer-remote-run-on-amlcompute_1589985163_b05fc2f2',
#  'target': 'cpucluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-05-20T14:43:07.908376Z',
#  'endTimeUtc': '2020-05-20T14:45:00.869349Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '21580dda-ce18-4709-803a-d936627634ec',
#   'AzureML.DerivedImageName': 'azureml/azureml_25f143aa9c70f6d08bf525d14da8e04f',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json',
#   'model_type': 'classification',
#   'explainer': 'tabular'},
#  'inputDatasets': [{'dataset': {'id': 'd7b9cba4-3789-4b54-8fa8-a227c6da81fa'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'attrition', 'mechanism': 'Direct'}}],
#  'runDefinition': {'script': 'train_explain.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'cpucluster',
#   'dataReferences': {},
#   'data': {'attrition': {'dataLocation': {'dataset': {'id': 'd7b9cba4-3789-4b54-8fa8-a227c6da81fa'},
#      'dataPath': None},
#     'createOutputDirectories': False,
#     'mechanism': 'Direct',
#     'environmentVariableName': 'attrition',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment explainer-remote-run-on-amlcompute Environment',
#    'version': 'Autosave_2020-05-20T14:32:44Z_ebf402c0',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults==1.0.76',
#         'azureml-core==1.0.76',
#         'azureml-telemetry==1.0.76',
#         'azureml-dataprep==1.1.31',
#         'joblib==0.14.0',
#         'sklearn-pandas==1.7.0',
#         'pandas==0.23.4',
#         'azureml-contrib-interpret']},
#       'scikit-learn==0.20.3'],
#      'name': 'azureml_e158b0e389821d00d72b205b3dcc7bbc'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'itpCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=WogHjjOvlEfAPo27qTQwTlG%2F6hoemi8iXF%2F9EuYOGrM%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/55_azureml-execution-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt?sv=2019-02-02&sr=b&sig=ANWntfQFIyet%2FDAuzqSkbNrDSJDQLTkNdj9hmt01Hgw%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/65_job_prep-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt?sv=2019-02-02&sr=b&sig=lNcG%2FJB2UigGfKM1bSCjvGtDwKOmHLX5ZDzLgdWPBUU%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=2RUSz8DnEnSQQOvWLn9YEzXWTuxjxAYurzmpm6Dx%2BJc%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/75_job_post-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt?sv=2019-02-02&sr=b&sig=C4RRtObzF2pE894yA%2BpgQuHJayOO3l6PM1WY6lxBmgM%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/process_info.json': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=rnaU4YVT64UWue1D7qo5PO6wL03ZnsQl1wKENdqA3P0%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'azureml-logs/process_status.json': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=jd9TWrnvo9VxYbnCe%2FwITTnitedtc9JNFax5%2FsrRjw0%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'logs/azureml/102_azureml.log': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/logs/azureml/102_azureml.log?sv=2019-02-02&sr=b&sig=iTz6vnSjTlFcWY3KIN1Hhk4DVDNDOVq6Y85iAF75zGM%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r',
#   'logs/azureml/azureml.log': 'https://amlwksphol0408859175.blob.core.windows.net/azureml/ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/logs/azureml/azureml.log?sv=2019-02-02&sr=b&sig=oTumv9NS5dNcHaHCCR8%2BAnWXVcYMmY8qMMajwQFxZRk%3D&st=2020-05-20T14%3A35%3A03Z&se=2020-05-20T22%3A45%3A03Z&sp=r'}}

# %% [markdown]
# ## Download
# ### 1. Download model explanation data.

# %%
from azureml.contrib.interpret.explanation.explanation_client import ExplanationClient

# Get model explanation data
client = ExplanationClient.from_run(run)
#global_explanation = client.download_model_explanation()

# %%
# Get the top k (e.g., 4) most important features with their importance values
global_explanation_topk = client.download_model_explanation(top_k=4)
global_importance_values = global_explanation_topk.get_ranked_global_values()
global_importance_names = global_explanation_topk.get_ranked_global_names()
# Out:
# ---------------------------------------------------------------------------
# ErrorResponseException                    Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/workspace_client.py in _execute_with_arguments(self, func, args_list, *args, **kwargs)
#      86             else:
# ---> 87                 return self._call_api(func, *args_list, **kwargs)
#      88         except ErrorResponseException as e:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/clientbase.py in _call_api(self, func, *args, **kwargs)
#     229             else:
# --> 230                 return self._execute_with_base_arguments(func, *args, **kwargs)
#     231
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/clientbase.py in _execute_with_base_arguments(self, func, *args, **kwargs)
#     305         return ClientBase._execute_func_internal(
# --> 306             back_off, total_retry, self._logger, func, _noop_reset, *args, **kwargs)
#     307
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/clientbase.py in _execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     320             except Exception as error:
# --> 321                 left_retry = cls._handle_retry(back_off, left_retry, total_retry, error, logger, func)
#     322
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/clientbase.py in _handle_retry(cls, back_off, left_retry, total_retry, error, logger, func)
#     369             elif error.response.status_code < 500:
# --> 370                 raise error
#     371         elif not isinstance(error, RETRY_EXCEPTIONS):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/clientbase.py in _execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     318             try:
# --> 319                 return func(*args, **kwargs)
#     320             except Exception as error:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/operations/artifact_operations.py in get_content_information(self, subscription_id, resource_group_name, workspace_name, origin, container, path, custom_headers, raw, **operation_config)
#     586         if response.status_code not in [200]:
# --> 587             raise models.ErrorResponseException(self._deserialize, response)
#     588
#
# ErrorResponseException: (UserError) Cannot find Artifact with ID ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/explanation/97c2ffda-5e06-4065-8ab0-e88662f0b319/rich_metadata.interpret.json in Partition c16651e1-280d-437a-b5dd-7cdf5b8212c2.
#
# During handling of the above exception, another exception occurred:
#
# ServiceException                          Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/artifacts_client.py in download_artifact(self, origin, container, path, output_file_path, _validate_checksum)
#     255             content_info = self._execute_with_workspace_arguments(self._client.artifact.get_content_information,
# --> 256                                                                   origin, container, path)
#     257             if not content_info:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/workspace_client.py in _execute_with_workspace_arguments(self, func, *args, **kwargs)
#      70     def _execute_with_workspace_arguments(self, func, *args, **kwargs):
# ---> 71         return self._execute_with_arguments(func, copy.deepcopy(self._workspace_arguments), *args, **kwargs)
#      72
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/workspace_client.py in _execute_with_arguments(self, func, args_list, *args, **kwargs)
#      88         except ErrorResponseException as e:
# ---> 89             raise ServiceException(e)
#      90
#
# ServiceException: ServiceException:
# 	Code: 404
# 	Message: (UserError) Cannot find Artifact with ID ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/explanation/97c2ffda-5e06-4065-8ab0-e88662f0b319/rich_metadata.interpret.json in Partition c16651e1-280d-437a-b5dd-7cdf5b8212c2.
# 	Details:
#
# 	Headers: {
# 	    "Date": "Wed, 20 May 2020 14:50:57 GMT",
# 	    "Content-Type": "application/json; charset=utf-8",
# 	    "Transfer-Encoding": "chunked",
# 	    "Connection": "keep-alive",
# 	    "Vary": "Accept-Encoding",
# 	    "Request-Context": "appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d",
# 	    "x-ms-response-type": "error",
# 	    "x-ms-client-request-id": "5749828a-e414-41f2-8221-52944ab3be9e",
# 	    "x-ms-client-session-id": "",
# 	    "Strict-Transport-Security": "max-age=15724800; includeSubDomains; preload",
# 	    "Content-Encoding": "gzip"
# 	}
# 	InnerException: {
#     "additional_properties": {},
#     "error": {
#         "additional_properties": {},
#         "code": "UserError",
#         "message": "Cannot find Artifact with ID ExperimentRun/dcid.explainer-remote-run-on-amlcompute_1589985163_b05fc2f2/explanation/97c2ffda-5e06-4065-8ab0-e88662f0b319/rich_metadata.interpret.json in Partition c16651e1-280d-437a-b5dd-7cdf5b8212c2.",
#         "details_uri": null,
#         "target": null,
#         "details": [],
#         "inner_error": {
#             "additional_properties": {},
#             "code": "NotFoundError",
#             "inner_error": null
#         },
#         "debug_info": null,
#         "message_format": null,
#         "message_parameters": null,
#         "reference_code": null
#     },
#     "correlation": {
#         "operation": "cde57d99e59ce94f9b47e93b9b54fe50",
#         "request": "8e090ea86313ea99"
#     },
#     "environment": "westus",
#     "location": "westus",
#     "time": {}
# }
#
# During handling of the above exception, another exception occurred:
#
# UserErrorException                        Traceback (most recent call last)
# <ipython-input-18-9218b142e56a> in <module>
#       1 # Get the top k (e.g., 4) most important features with their importance values
# ----> 2 global_explanation_topk = client.download_model_explanation(top_k=4)
#       3 global_importance_values = global_explanation_topk.get_ranked_global_values()
#       4 global_importance_names = global_explanation_topk.get_ranked_global_names()
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/interpret/_internal/explanation_client.py in download_model_explanation(self, explanation_id, top_k, comment, raw, engineered)
#     810             module_logger.debug('Downloading explanations with top k features')
#     811             return self._download_explanation_top_k(explanation_id=explanation_id, top_k=top_k, comment=comment,
# --> 812                                                     raw=raw, engineered=engineered)
#     813
#     814     def _download_explanation_as_batch(self, explanation_id=None, comment=None, raw=None, engineered=None):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/interpret/_internal/explanation_client.py in _download_explanation_top_k(self, explanation_id, top_k, comment, raw, engineered)
#    1178             metadata_artifact_name = explanation_asset.meta[History.METADATA_ARTIFACT]
#    1179             storage_metadata = _download_artifact(self._run, download_dir, metadata_artifact_name, mli_extension,
# -> 1180                                                   explanation_id=explanation_id)
#    1181             # classification and local importances are stored differently in v2/3 assets than in v1
#    1182             if ExplainType.MODEL in explanation_asset.meta:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/interpret/_internal/explanation_client.py in _download_artifact(run, download_dir, artifact_name, extension, explanation_id, file_type)
#      82     file_name = '{}{}{}.{}'.format(artifact_path, artifact_name, interpret_string, file_type)
#      83     path = os.path.join(download_dir, file_name)
# ---> 84     run.download_file(file_name, path)
#      85     with open(path, 'rb') as f:
#      86         file_string = f.read()
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/run.py in wrapped(self, *args, **kwargs)
#      46                                      "therefore, the {} cannot upload files, or log file backed metrics.".format(
#      47                                          self, self.__class__.__name__))
# ---> 48         return func(self, *args, **kwargs)
#      49     return wrapped
#      50
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/run.py in download_file(self, name, output_file_path, _validate_checksum)
#    1879
#    1880         self._client.artifacts.download_artifact(RUN_ORIGIN, self._container, name, output_file_path,
# -> 1881                                                  _validate_checksum)
#    1882
#    1883     @_check_for_data_container_id
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/artifacts_client.py in download_artifact(self, origin, container, path, output_file_path, _validate_checksum)
#     261                                _validate_check_sum=_validate_checksum)
#     262         except HttpOperationError as operation_error:
# --> 263             self._handle_http_operation_error(operation_error, origin, container, path)
#     264
#     265     def download_artifacts_from_prefix(self, origin, container, prefix=None, output_directory=None, output_paths=None,
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/_restclient/artifacts_client.py in _handle_http_operation_error(self, operation_error, origin, container, path, prefix)
#     506             raise UserErrorException("{0} with path {1} was not found,\n"
#     507                                      "available files include: "
# --> 508                                      "{2}.".format(type_string, path, ",".join(existing_files)))
#     509         else:
#     510             raise operation_error
#
# UserErrorException: UserErrorException:
# 	Message: File with path explanation/97c2ffda-5e06-4065-8ab0-e88662f0b319/rich_metadata.interpret.json was not found,
# available files include: azureml-logs/20_image_build_log.txt,azureml-logs/55_azureml-execution-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/65_job_prep-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/70_driver_log.txt,azureml-logs/75_job_post-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/process_info.json,azureml-logs/process_status.json,explanation/97c2ffda/classes.interpret.json,explanation/97c2ffda/eval_data_viz.interpret.json,explanation/97c2ffda/expected_values.interpret.json,explanation/97c2ffda/features.interpret.json,explanation/97c2ffda/global_names/0.interpret.json,explanation/97c2ffda/global_rank/0.interpret.json,explanation/97c2ffda/global_values/0.interpret.json,explanation/97c2ffda/local_importance_values.interpret.json,explanation/97c2ffda/per_class_names/0.interpret.json,explanation/97c2ffda/per_class_rank/0.interpret.json,explanation/97c2ffda/per_class_values/0.interpret.json,explanation/97c2ffda/rich_metadata.interpret.json,explanation/97c2ffda/visualization_dict.interpret.json,explanation/97c2ffda/ys_pred_proba_viz.interpret.json,explanation/97c2ffda/ys_pred_viz.interpret.json,logs/azureml/102_azureml.log,logs/azureml/azureml.log,original_model.pkl,outputs/log_reg.pkl,outputs/x_test.pkl,x_test_ibm.pkl.
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "message": "File with path explanation/97c2ffda-5e06-4065-8ab0-e88662f0b319/rich_metadata.interpret.json was not found,\navailable files include: azureml-logs/20_image_build_log.txt,azureml-logs/55_azureml-execution-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/65_job_prep-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/70_driver_log.txt,azureml-logs/75_job_post-tvmps_88bb717ed42f063078197b445b5195f23f59fe98e9e8917b1ce2d97490180688_d.txt,azureml-logs/process_info.json,azureml-logs/process_status.json,explanation/97c2ffda/classes.interpret.json,explanation/97c2ffda/eval_data_viz.interpret.json,explanation/97c2ffda/expected_values.interpret.json,explanation/97c2ffda/features.interpret.json,explanation/97c2ffda/global_names/0.interpret.json,explanation/97c2ffda/global_rank/0.interpret.json,explanation/97c2ffda/global_values/0.interpret.json,explanation/97c2ffda/local_importance_values.interpret.json,explanation/97c2ffda/per_class_names/0.interpret.json,explanation/97c2ffda/per_class_rank/0.interpret.json,explanation/97c2ffda/per_class_values/0.interpret.json,explanation/97c2ffda/rich_metadata.interpret.json,explanation/97c2ffda/visualization_dict.interpret.json,explanation/97c2ffda/ys_pred_proba_viz.interpret.json,explanation/97c2ffda/ys_pred_viz.interpret.json,logs/azureml/102_azureml.log,logs/azureml/azureml.log,original_model.pkl,outputs/log_reg.pkl,outputs/x_test.pkl,x_test_ibm.pkl."
#     }
# }

# %%
print('global importance values: {}'.format(global_importance_values))
print('global importance names: {}'.format(global_importance_names))

# %% [markdown]
# ## See model's files

# %%
print(run.get_file_names())

# %% [markdown]
# ### 2. Download model and test set files

# %%
# retrieve model for visualization and deployment
from azureml.core.model import Model
import joblib

# Download test dataset file
run.download_file('x_test_ibm.pkl')
x_test = joblib.load('x_test_ibm.pkl')

# Download trained model
run.download_file('original_model.pkl')
original_model = joblib.load('original_model.pkl')

original_model

# %% [markdown]
# ## Visualize
# Load the visualization dashboard (**currently broken in JupyterLab**)

# %%
from interpret_community.widget import ExplanationDashboard

# %%
ExplanationDashboard(global_explanation, original_model, datasetX=x_test)
